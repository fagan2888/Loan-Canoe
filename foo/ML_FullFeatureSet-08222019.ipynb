# %% [markdown]
# **This is a preliminary ML script to determine the best models for our project data.**

# %%
# %matplotlib inline

import os

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()

# %% [markdown]
# **Import 2017 sample of 25,000 observations.**  Note import warning:"Columns (29,30,39,40) have mixed types. Specify dtype option on import or set low_memory=False."

# %%
filepath = os.path.abspath(os.path.join( "..", "fixtures", "hmda2017sample.csv"))
DATA = pd.read_csv(filepath, low_memory=False)

# %% [markdown]
# **Drop features which are redundant or have mostly missing data + Drop first column
# ALSO: drop msamd_name and census_tract_number, as they make each bin of data too granular**

# %%
DATA = DATA.drop(DATA.columns[0], axis=1)

DATA = DATA.drop(['rate_spread', 
        'sequence_number', 
        'respondent_id',
        'state_name',
        'county_name',
        'edit_status_name', 
        'denial_reason_name_3', 
        'denial_reason_name_2', 
        'denial_reason_name_1', 
        'co_applicant_race_name_5', 
        'co_applicant_race_name_4', 
        'co_applicant_race_name_3', 
        'co_applicant_race_name_2',
        'census_tract_number',
        'application_date_indicator', 
        'applicant_race_name_5', 
        'applicant_race_name_4', 
        'applicant_race_name_3', 
        'applicant_race_name_2', 
        'agency_name'], 
        axis=1)

# %%
DATA['locality_type'] = None

# %%
cloc = DATA.columns.get_loc('locality_type')

i = 0
for x in DATA['msamd_name'].isna():
    if x == True:
        DATA.iat[i, cloc]= 0
        
    else: 
        DATA.iat[i, cloc]= 1
        
    i+=1
        
pd.crosstab(DATA['msamd_name'],DATA['locality_type'], margins=True, dropna=False) #dropna=False
DATA[['msamd_name', 'locality_type']]
# Out:
#                                               msamd_name locality_type
# 0                        San Antonio, New Braunfels - TX             1
# 1                                            Joplin - MO             1
# 2               Sacramento, Roseville, Arden-Arcade - CA             1
# 3                        Seattle, Bellevue, Everett - WA             1
# 4                                   Kansas City - MO, KS             1
# 5                  Allentown, Bethlehem, Easton - PA, NJ             1
# 6                                   Killeen, Temple - TX             1
# 7                                            Wausau - WI             1
# 8                Houston, The Woodlands, Sugar Land - TX             1
# 9                                                    NaN             0
# 10                      Miami, Miami Beach, Kendall - FL             1
# 11                     Augusta, Richmond County - GA, SC             1
# 12                                Cleveland, Elyria - OH             1
# 13           Chicago, Naperville, Arlington Heights - IL             1
# 14               Riverside, San Bernardino, Ontario - CA             1
# 15     Washington, Arlington, Alexandria - DC, VA, MD...             1
# 16                                       Pittsburgh - PA             1
# 17       Nashville-Davidson, Murfreesboro, Franklin - TN             1
# 18                                                   NaN             0
# 19                       Anaheim, Santa Ana, Irvine - CA             1
# 20                                                   NaN             0
# 21                                      Provo, Orem - UT             1
# 22                                      Bakersfield - CA             1
# 23                         Denver, Aurora, Lakewood - CO             1
# 24             Crestview, Fort Walton Beach, Destin - FL             1
# 25                                  Kansas City - MO, KS             1
# 26                    Cambridge, Newton, Framingham - MA             1
# 27                                 Colorado Springs - CO             1
# 28                Tampa, St. Petersburg, Clearwater - FL             1
# 29                       Anaheim, Santa Ana, Irvine - CA             1
# ...                                                  ...           ...
# 24970       New York, Jersey City, White Plains - NY, NJ             1
# 24971                             Cleveland, Elyria - OH             1
# 24972        Chicago, Naperville, Arlington Heights - IL             1
# 24973                                                NaN             0
# 24974               Milwaukee, Waukesha, West Allis - WI             1
# 24975                      Denver, Aurora, Lakewood - CO             1
# 24976                                 St. Louis - MO, IL             1
# 24977                               Memphis - TN, MS, AR             1
# 24978                                   Provo, Orem - UT             1
# 24979                             Canton, Massillon - OH             1
# 24980                Dutchess County, Putnam County - NY             1
# 24981        Chicago, Naperville, Arlington Heights - IL             1
# 24982                       La Crosse, Onalaska - WI, MN             1
# 24983        Hartford, West Hartford, East Hartford - CT             1
# 24984              Youngstown, Warren, Boardman - OH, PA             1
# 24985                                     Lancaster - PA             1
# 24986                     Kahului, Wailuku, Lahaina - HI             1
# 24987            Riverside, San Bernardino, Ontario - CA             1
# 24988       New York, Jersey City, White Plains - NY, NJ             1
# 24989                               Kansas City - MO, KS             1
# 24990                    Oakland, Hayward, Berkeley - CA             1
# 24991                                 Worcester - MA, CT             1
# 24992                     Phoenix, Mesa, Scottsdale - AZ             1
# 24993       New York, Jersey City, White Plains - NY, NJ             1
# 24994                                 Coeur D'Alene - ID             1
# 24995                         Dallas, Plano, Irving - TX             1
# 24996        Little Rock, North Little Rock, Conway - AR             1
# 24997                                         Elgin - IL             1
# 24998                               Memphis - TN, MS, AR             1
# 24999                    Oakland, Hayward, Berkeley - CA             1
#
# [25000 rows x 2 columns]

# %%
DATA.describe(include='all')
# Out:
#         tract_to_msamd_income    population  minority_population  \
# count            25000.000000  25000.000000         25000.000000
# unique                    NaN           NaN                  NaN
# top                       NaN           NaN                  NaN
# freq                      NaN           NaN                  NaN
# mean               111.397555   5713.388400            31.196988
# std                 40.126879   3294.295145            26.444629
# min                  0.000000      0.000000             0.000000
# 25%                 85.459999   3824.000000            10.090000
# 50%                106.370003   5124.500000            22.080000
# 75%                131.699997   6766.000000            46.299999
# max                457.350006  53812.000000           100.000000
#
#         number_of_owner_occupied_units  number_of_1_to_4_family_units  \
# count                     25000.000000                   25000.000000
# unique                             NaN                            NaN
# top                                NaN                            NaN
# freq                               NaN                            NaN
# mean                       1453.986800                    1983.270800
# std                         890.954715                    1096.396276
# min                           0.000000                       0.000000
# 25%                         919.000000                    1340.750000
# 50%                        1320.000000                    1813.000000
# 75%                        1791.000000                    2387.000000
# max                       19529.000000                   25391.000000
#
#         loan_amount_000s  hud_median_family_income  applicant_income_000s  \
# count        25000.00000               25000.00000           21758.000000
# unique               NaN                       NaN                    NaN
# top                  NaN                       NaN                    NaN
# freq                 NaN                       NaN                    NaN
# mean           236.43560               70736.62400             105.568435
# std            826.32896               13831.63976             142.214077
# min              1.00000               15800.00000               1.000000
# 25%            107.00000               62100.00000              50.000000
# 50%            180.00000               69200.00000              78.000000
# 75%            281.00000               75700.00000             120.000000
# max          99999.00000              131500.00000            7485.000000
#
#        state_abbr                                purchaser_type_name  ...  \
# count       25000                                              25000  ...
# unique         50                                                 10  ...
# top            CA  Loan was not originated or was not sold in cal...  ...
# freq         2746                                              12950  ...
# mean          NaN                                                NaN  ...
# std           NaN                                                NaN  ...
# min           NaN                                                NaN  ...
# 25%           NaN                                                NaN  ...
# 50%           NaN                                                NaN  ...
# 75%           NaN                                                NaN  ...
# max           NaN                                                NaN  ...
#
#        co_applicant_sex_name co_applicant_race_name_1  \
# count                  25000                    25000
# unique                     5                        8
# top          No co-applicant          No co-applicant
# freq                   13138                    13138
# mean                     NaN                      NaN
# std                      NaN                      NaN
# min                      NaN                      NaN
# 25%                      NaN                      NaN
# 50%                      NaN                      NaN
# 75%                      NaN                      NaN
# max                      NaN                      NaN
#
#        co_applicant_ethnicity_name as_of_year applicant_sex_name  \
# count                        25000    25000.0              25000
# unique                           5        NaN                  4
# top                No co-applicant        NaN               Male
# freq                         13138        NaN              14027
# mean                           NaN     2017.0                NaN
# std                            NaN        0.0                NaN
# min                            NaN     2017.0                NaN
# 25%                            NaN     2017.0                NaN
# 50%                            NaN     2017.0                NaN
# 75%                            NaN     2017.0                NaN
# max                            NaN     2017.0                NaN
#
#        applicant_race_name_1 applicant_ethnicity_name agency_abbr  \
# count                  25000                    25000       25000
# unique                     7                        4           6
# top                    White   Not Hispanic or Latino         HUD
# freq                   16162                    16986       12276
# mean                     NaN                      NaN         NaN
# std                      NaN                      NaN         NaN
# min                      NaN                      NaN         NaN
# 25%                      NaN                      NaN         NaN
# 50%                      NaN                      NaN         NaN
# 75%                      NaN                      NaN         NaN
# max                      NaN                      NaN         NaN
#
#        action_taken_name locality_type
# count              25000       25000.0
# unique                 7           2.0
# top      Loan originated           1.0
# freq               12754       22105.0
# mean                 NaN           NaN
# std                  NaN           NaN
# min                  NaN           NaN
# 25%                  NaN           NaN
# 50%                  NaN           NaN
# 75%                  NaN           NaN
# max                  NaN           NaN
#
# [11 rows x 28 columns]

# %%
print("DATA dimensions: {}".format(DATA.shape))
# Out:
# DATA dimensions: (25000, 28)

# %% [markdown]
# **Write the initial script using subset of features which are already int or float, plus the target**
#
# **IDEAS: discard file closed, call 'application approved but not accepted" a 1 or discard, discard 'application withdrawn by applicant'.  Concern about overfitting if we leave too much stuff in.**

# %%
DATA['action_taken'] = DATA.action_taken_name.apply(lambda x: 1 if x in ['Loan purchased by the institution', 'Loan originated'] else 0)
pd.crosstab(DATA['action_taken_name'],DATA['action_taken'], margins=True)
# Out:
# action_taken                                           0      1    All
# action_taken_name
# Application approved but not accepted                700      0    700
# Application denied by financial institution         3923      0   3923
# Application withdrawn by applicant                  2952      0   2952
# File closed for incompleteness                      1096      0   1096
# Loan originated                                        0  12754  12754
# Loan purchased by the institution                      0   3573   3573
# Preapproval request denied by financial institu...     2      0      2
# All                                                 8673  16327  25000

# %% [markdown]
# **ACTION: look at imputing income using hud household median income rather than mean**

# %%
DATA_targ_numeric = DATA[['action_taken',
            'tract_to_msamd_income', 
            'population', 
            'minority_population', 
            'number_of_owner_occupied_units', 
            'number_of_1_to_4_family_units', 
            'loan_amount_000s', 
            'hud_median_family_income', 
            'applicant_income_000s', 'locality_type'
            ]]
#resolve missing values in applicant_income_000s
DATA_targ_numeric.fillna(DATA_targ_numeric.mean(), inplace=True)
DATA_targ_numeric.info()
DATA_basefile = DATA_targ_numeric
# Out:
# C:\Users\akx00\Anaconda3\lib\site-packages\pandas\core\generic.py:6130: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25000 entries, 0 to 24999
# Data columns (total 10 columns):
# action_taken                      25000 non-null int64
# tract_to_msamd_income             25000 non-null float64
# population                        25000 non-null int64
# minority_population               25000 non-null float64
# number_of_owner_occupied_units    25000 non-null int64
# number_of_1_to_4_family_units     25000 non-null int64
# loan_amount_000s                  25000 non-null int64
# hud_median_family_income          25000 non-null int64
# applicant_income_000s             25000 non-null float64
# locality_type                     25000 non-null int64
# dtypes: float64(3), int64(7)
# memory usage: 1.9 MB

# %% [markdown]
# **Use one-hot encoding via Pandas, concatenate to the rest of the data frame.**
#
# Reference link:
# https://stackoverflow.com/questions/37292872/how-can-i-one-hot-encode-in-python

# %%
DATA = DATA.drop(['action_taken_name', 'msamd_name'], axis=1)
DATA.columns
# Out:
# Index(['tract_to_msamd_income', 'population', 'minority_population',
#        'number_of_owner_occupied_units', 'number_of_1_to_4_family_units',
#        'loan_amount_000s', 'hud_median_family_income', 'applicant_income_000s',
#        'state_abbr', 'purchaser_type_name', 'property_type_name',
#        'preapproval_name', 'owner_occupancy_name', 'loan_type_name',
#        'loan_purpose_name', 'lien_status_name', 'hoepa_status_name',
#        'co_applicant_sex_name', 'co_applicant_race_name_1',
#        'co_applicant_ethnicity_name', 'as_of_year', 'applicant_sex_name',
#        'applicant_race_name_1', 'applicant_ethnicity_name', 'agency_abbr',
#        'locality_type', 'action_taken'],
#       dtype='object')

# %%
non_categorical_features = ['action_taken',
                        'tract_to_msamd_income', 
                        'population', 
                        'minority_population', 
                        'number_of_owner_occupied_units', 
                        'number_of_1_to_4_family_units', 
                        'loan_amount_000s', 
                        'hud_median_family_income', 
                        'applicant_income_000s',
                        'locality_type'
                       ]

# %%
for categorical_feature in list(DATA.columns):
    if categorical_feature not in non_categorical_features:
        DATA[categorical_feature] = DATA[categorical_feature].astype('category')
        dummies = pd.get_dummies(DATA[categorical_feature], prefix=categorical_feature)
        DATA_basefile = pd.concat([DATA_basefile, dummies], axis=1)
        
DATA_basefile.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25000 entries, 0 to 24999
# Data columns (total 132 columns):
# action_taken                                                                                                     int64
# tract_to_msamd_income                                                                                            float64
# population                                                                                                       int64
# minority_population                                                                                              float64
# number_of_owner_occupied_units                                                                                   int64
# number_of_1_to_4_family_units                                                                                    int64
# loan_amount_000s                                                                                                 int64
# hud_median_family_income                                                                                         int64
# applicant_income_000s                                                                                            float64
# locality_type                                                                                                    int64
# state_abbr_AL                                                                                                    uint8
# state_abbr_AR                                                                                                    uint8
# state_abbr_AZ                                                                                                    uint8
# state_abbr_CA                                                                                                    uint8
# state_abbr_CO                                                                                                    uint8
# state_abbr_CT                                                                                                    uint8
# state_abbr_DC                                                                                                    uint8
# state_abbr_DE                                                                                                    uint8
# state_abbr_FL                                                                                                    uint8
# state_abbr_GA                                                                                                    uint8
# state_abbr_HI                                                                                                    uint8
# state_abbr_IA                                                                                                    uint8
# state_abbr_ID                                                                                                    uint8
# state_abbr_IL                                                                                                    uint8
# state_abbr_IN                                                                                                    uint8
# state_abbr_KS                                                                                                    uint8
# state_abbr_KY                                                                                                    uint8
# state_abbr_LA                                                                                                    uint8
# state_abbr_MA                                                                                                    uint8
# state_abbr_MD                                                                                                    uint8
# state_abbr_ME                                                                                                    uint8
# state_abbr_MI                                                                                                    uint8
# state_abbr_MN                                                                                                    uint8
# state_abbr_MO                                                                                                    uint8
# state_abbr_MS                                                                                                    uint8
# state_abbr_MT                                                                                                    uint8
# state_abbr_NC                                                                                                    uint8
# state_abbr_ND                                                                                                    uint8
# state_abbr_NE                                                                                                    uint8
# state_abbr_NH                                                                                                    uint8
# state_abbr_NJ                                                                                                    uint8
# state_abbr_NM                                                                                                    uint8
# state_abbr_NV                                                                                                    uint8
# state_abbr_NY                                                                                                    uint8
# state_abbr_OH                                                                                                    uint8
# state_abbr_OK                                                                                                    uint8
# state_abbr_OR                                                                                                    uint8
# state_abbr_PA                                                                                                    uint8
# state_abbr_PR                                                                                                    uint8
# state_abbr_RI                                                                                                    uint8
# state_abbr_SC                                                                                                    uint8
# state_abbr_TN                                                                                                    uint8
# state_abbr_TX                                                                                                    uint8
# state_abbr_UT                                                                                                    uint8
# state_abbr_VA                                                                                                    uint8
# state_abbr_VT                                                                                                    uint8
# state_abbr_WA                                                                                                    uint8
# state_abbr_WI                                                                                                    uint8
# state_abbr_WV                                                                                                    uint8
# state_abbr_WY                                                                                                    uint8
# purchaser_type_name_Affiliate institution                                                                        uint8
# purchaser_type_name_Commercial bank, savings bank or savings association                                         uint8
# purchaser_type_name_Fannie Mae (FNMA)                                                                            uint8
# purchaser_type_name_Farmer Mac (FAMC)                                                                            uint8
# purchaser_type_name_Freddie Mac (FHLMC)                                                                          uint8
# purchaser_type_name_Ginnie Mae (GNMA)                                                                            uint8
# purchaser_type_name_Life insurance company, credit union, mortgage bank, or finance company                      uint8
# purchaser_type_name_Loan was not originated or was not sold in calendar year covered by register                 uint8
# purchaser_type_name_Other type of purchaser                                                                      uint8
# purchaser_type_name_Private securitization                                                                       uint8
# property_type_name_Manufactured housing                                                                          uint8
# property_type_name_Multifamily dwelling                                                                          uint8
# property_type_name_One-to-four family dwelling (other than manufactured housing)                                 uint8
# preapproval_name_Not applicable                                                                                  uint8
# preapproval_name_Preapproval was not requested                                                                   uint8
# preapproval_name_Preapproval was requested                                                                       uint8
# owner_occupancy_name_Not applicable                                                                              uint8
# owner_occupancy_name_Not owner-occupied as a principal dwelling                                                  uint8
# owner_occupancy_name_Owner-occupied as a principal dwelling                                                      uint8
# loan_type_name_Conventional                                                                                      uint8
# loan_type_name_FHA-insured                                                                                       uint8
# loan_type_name_FSA/RHS-guaranteed                                                                                uint8
# loan_type_name_VA-guaranteed                                                                                     uint8
# loan_purpose_name_Home improvement                                                                               uint8
# loan_purpose_name_Home purchase                                                                                  uint8
# loan_purpose_name_Refinancing                                                                                    uint8
# lien_status_name_Not applicable                                                                                  uint8
# lien_status_name_Not secured by a lien                                                                           uint8
# lien_status_name_Secured by a first lien                                                                         uint8
# lien_status_name_Secured by a subordinate lien                                                                   uint8
# hoepa_status_name_HOEPA loan                                                                                     uint8
# hoepa_status_name_Not a HOEPA loan                                                                               uint8
# co_applicant_sex_name_Female                                                                                     uint8
# co_applicant_sex_name_Information not provided by applicant in mail, Internet, or telephone application          uint8
# co_applicant_sex_name_Male                                                                                       uint8
# co_applicant_sex_name_No co-applicant                                                                            uint8
# co_applicant_sex_name_Not applicable                                                                             uint8
# co_applicant_race_name_1_American Indian or Alaska Native                                                        uint8
# co_applicant_race_name_1_Asian                                                                                   uint8
# co_applicant_race_name_1_Black or African American                                                               uint8
# co_applicant_race_name_1_Information not provided by applicant in mail, Internet, or telephone application       uint8
# co_applicant_race_name_1_Native Hawaiian or Other Pacific Islander                                               uint8
# co_applicant_race_name_1_No co-applicant                                                                         uint8
# co_applicant_race_name_1_Not applicable                                                                          uint8
# co_applicant_race_name_1_White                                                                                   uint8
# co_applicant_ethnicity_name_Hispanic or Latino                                                                   uint8
# co_applicant_ethnicity_name_Information not provided by applicant in mail, Internet, or telephone application    uint8
# co_applicant_ethnicity_name_No co-applicant                                                                      uint8
# co_applicant_ethnicity_name_Not Hispanic or Latino                                                               uint8
# co_applicant_ethnicity_name_Not applicable                                                                       uint8
# as_of_year_2017                                                                                                  uint8
# applicant_sex_name_Female                                                                                        uint8
# applicant_sex_name_Information not provided by applicant in mail, Internet, or telephone application             uint8
# applicant_sex_name_Male                                                                                          uint8
# applicant_sex_name_Not applicable                                                                                uint8
# applicant_race_name_1_American Indian or Alaska Native                                                           uint8
# applicant_race_name_1_Asian                                                                                      uint8
# applicant_race_name_1_Black or African American                                                                  uint8
# applicant_race_name_1_Information not provided by applicant in mail, Internet, or telephone application          uint8
# applicant_race_name_1_Native Hawaiian or Other Pacific Islander                                                  uint8
# applicant_race_name_1_Not applicable                                                                             uint8
# applicant_race_name_1_White                                                                                      uint8
# applicant_ethnicity_name_Hispanic or Latino                                                                      uint8
# applicant_ethnicity_name_Information not provided by applicant in mail, Internet, or telephone application       uint8
# applicant_ethnicity_name_Not Hispanic or Latino                                                                  uint8
# applicant_ethnicity_name_Not applicable                                                                          uint8
# agency_abbr_CFPB                                                                                                 uint8
# agency_abbr_FDIC                                                                                                 uint8
# agency_abbr_FRS                                                                                                  uint8
# agency_abbr_HUD                                                                                                  uint8
# agency_abbr_NCUA                                                                                                 uint8
# agency_abbr_OCC                                                                                                  uint8
# dtypes: float64(3), int64(7), uint8(122)
# memory usage: 4.8 MB

# %%
tofilepath = os.path.abspath(os.path.join( "..", "fixtures", "hmda2017sample_alltest_state_localitytest.csv"))
DATA_basefile.to_csv(tofilepath, index=False)

# %%
# Determine the shape of the data
print("{} instances with {} features\n".format(*DATA_basefile.shape))

# Determine the frequency of each class
print(pd.crosstab(index=DATA['action_taken'], columns="count"))
# Out:
# 25000 instances with 132 features
#
# col_0         count
# action_taken
# 0              8673
# 1             16327

# %% [markdown]
# ## Classification

# %%
from sklearn import metrics

from sklearn.naive_bayes import GaussianNB, BernoulliNB, MultinomialNB
from sklearn.linear_model import LogisticRegressionCV, LogisticRegression, SGDClassifier
from sklearn.svm import LinearSVC, NuSVC, SVC
from sklearn import tree
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import BaggingClassifier, ExtraTreesClassifier, RandomForestClassifier
from yellowbrick.classifier import ClassificationReport

# %%
X = DATA_basefile[DATA_basefile.columns[1:]]
y = DATA_basefile['action_taken']

# %%
def score_model(X, y, model, **kwargs):
    """
    Test various estimators.
    """ 
    #NOTE: for capstone add X_test, X_train, Y_test, Y_train for capstone code.  
    #Bake into model to see if it does cross validation, if not there do CV.
   
    scores = {'precision':[], 'recall':[], 'accuracy':[], 'f1':[]}
    
    # Instantiate the classification model and visualizer
    model.fit(X, y, **kwargs)  
    
    expected  = y
    predicted = model.predict(X)
        
    # Append our scores to the tracker
    scores['precision'].append(metrics.precision_score(expected, predicted, average="binary"))
    scores['recall'].append(metrics.recall_score(expected, predicted, average="binary"))
    scores['accuracy'].append(metrics.accuracy_score(expected, predicted))
    scores['f1'].append(metrics.f1_score(expected, predicted, average="binary"))
        
    # Compute and return F1 (harmonic mean of precision and recall), Precision, Recall, Accuracy   
    print("{}".format(model.__class__.__name__))    
    print("Validation scores are as follows:\n")
    print(pd.DataFrame(scores).mean())

# %%
# Try them all!
models = [
    GaussianNB(), 
    MultinomialNB(),
    BernoulliNB(),
    tree.DecisionTreeClassifier(),
    LinearDiscriminantAnalysis(),
    LogisticRegression(solver='lbfgs', max_iter=6000), 
    LogisticRegressionCV(cv=3, max_iter=6000), 
    BaggingClassifier(), 
    ExtraTreesClassifier(n_estimators=100), 
    RandomForestClassifier(n_estimators=100),
    LinearSVC(max_iter=6000)
]
for model in models:
    score_model(X, y, model)
# Out:
# GaussianNB
# Validation scores are as follows:
#
# precision    0.984344
# recall       0.781711
# accuracy     0.849320
# f1           0.871403
# dtype: float64
# MultinomialNB
# Validation scores are as follows:
#
# precision    0.722137
# recall       0.549642
# accuracy     0.567760
# f1           0.624191
# dtype: float64
# BernoulliNB
# Validation scores are as follows:
#
# precision    0.979029
# recall       0.814908
# accuracy     0.867720
# f1           0.889461
# dtype: float64
# DecisionTreeClassifier
# Validation scores are as follows:
#
# precision    1.000000
# recall       0.999939
# accuracy     0.999960
# f1           0.999969
# dtype: float64
# C:\Users\akx00\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:388: UserWarning: Variables are collinear.
#   warnings.warn("Variables are collinear.")
# LinearDiscriminantAnalysis
# Validation scores are as follows:
#
# precision    0.973493
# recall       0.814295
# accuracy     0.864240
# f1           0.886806
# dtype: float64
# LogisticRegression
# Validation scores are as follows:
#
# precision    0.653519
# recall       0.998591
# accuracy     0.653320
# f1           0.790018
# dtype: float64
# LogisticRegressionCV
# Validation scores are as follows:
#
# precision    0.779898
# recall       0.941018
# accuracy     0.788040
# f1           0.852916
# dtype: float64
# BaggingClassifier
# Validation scores are as follows:
#
# precision    0.998763
# recall       0.988975
# accuracy     0.992000
# f1           0.993845
# dtype: float64
# ExtraTreesClassifier
# Validation scores are as follows:
#
# precision    1.000000
# recall       0.999939
# accuracy     0.999960
# f1           0.999969
# dtype: float64
# RandomForestClassifier
# Validation scores are as follows:
#
# precision    0.999939
# recall       1.000000
# accuracy     0.999960
# f1           0.999969
# dtype: float64
# LinearSVC
# Validation scores are as follows:
#
# precision    0.653080
# recall       1.000000
# accuracy     0.653080
# f1           0.790137
# dtype: float64
# C:\Users\akx00\Anaconda3\lib\site-packages\sklearn\svm\base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)

# %%
def visualize_model(X, y, estimator):
    """
    Test various estimators.
    """ 
    # Instantiate the classification model and visualizer
    visualizer = ClassificationReport(
        model, classes=[1,0], 
        cmap="Blues", size=(600, 360)
    )
    visualizer.fit(X, y)  
    visualizer.score(X, y)
    visualizer.poof()  

for model in models:
    visualize_model(X, y, model)
# Out:
# C:\Users\akx00\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:388: UserWarning: Variables are collinear.
#   warnings.warn("Variables are collinear.")
